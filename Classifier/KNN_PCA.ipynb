# %%
from sklearn.cross_validation import train_test_split
from sklearn.metrics import f1_score
from sklearn import metrics
import pandas as pd
from sklearn.neural_network import MLPClassifier
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
path = 'default_of_credit_card_clients.csv'
train_x_y = pd.read_csv(path)

feature_list = ['LIMIT_BAL','SEX','EDUCATION','MARRIAGE','AGE','PAY_0','PAY_2','PAY_3',
                'PAY_4','PAY_5','PAY_6','BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4',
                'BILL_AMT5','BILL_AMT6','PAY_AMT1','PAY_AMT2','PAY_AMT3','PAY_AMT4',
                'PAY_AMT5','PAY_AMT6']

X = train_x_y[feature_list]
y = train_x_y.default_payment_next_month
#dimensional reduction


l = []
pca = PCA(n_components= 2)
X = pca.fit_transform(X)


for i in range(1,51):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    #‘sgd’ refers to stochastic gradient descent.
    #L2 penalty (regularization term) parameter.
    clf = KNeighborsClassifier(n_neighbors=8)

    clf.fit(X_train, y_train)
    y_pred_class = clf.predict(X_test)

    l.append(f1_score(y_test, y_pred_class, average='micro'))
    print("x_train,y_train score:", clf.score(X_train, y_train))
    print("x_test,y_test score:", clf.score(X_test, y_test))
    print("f1_score:", f1_score(y_test, y_pred_class, average='micro'))
    print("number of layers:", i)
    print(metrics.classification_report(y_test, y_pred_class))
    print('#################################')
print("F1 average:",sum(l) / 50)
# Out:
# /Users/bingqianshan/anaconda/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# x_train,y_train score: 0.79375
# x_test,y_test score: 0.7685
# f1_score: 0.7685
# number of layers: 1
#              precision    recall  f1-score   support
#
#           0       0.79      0.97      0.87      4663
#           1       0.40      0.08      0.13      1337
#
# avg / total       0.70      0.77      0.70      6000
#
# #################################
# x_train,y_train score: 0.795291666667
# x_test,y_test score: 0.7555
# f1_score: 0.7555
# number of layers: 2
#              precision    recall  f1-score   support
#
#           0       0.77      0.97      0.86      4596
#           1       0.38      0.07      0.12      1404
#
# avg / total       0.68      0.76      0.68      6000
#
# #################################
# x_train,y_train score: 0.791708333333
# x_test,y_test score: 0.775166666667
# f1_score: 0.775166666667
# number of layers: 3
#              precision    recall  f1-score   support
#
#           0       0.79      0.97      0.87      4721
#           1       0.36      0.07      0.12      1279
#
# avg / total       0.70      0.78      0.71      6000
#
# #################################
# x_train,y_train score: 0.79175
# x_test,y_test score: 0.770666666667
# f1_score: 0.770666666667
# number of layers: 4
#              precision    recall  f1-score   support
#
#           0       0.78      0.97      0.87      4652
#           1       0.44      0.08      0.13      1348
#
# avg / total       0.71      0.77      0.70      6000
#
# #################################
# x_train,y_train score: 0.791458333333
# x_test,y_test score: 0.768833333333
# f1_score: 0.768833333333
# number of layers: 5
#              precision    recall  f1-score   support
#
#           0       0.79      0.97      0.87      4687
#           1       0.35      0.07      0.11      1313
#
# avg / total       0.69      0.77      0.70      6000
#
# #################################
# x_train,y_train score: 0.791791666667
# x_test,y_test score: 0.771833333333
# f1_score: 0.771833333333
# number of layers: 6
#              precision    recall  f1-score   support
#
#           0       0.79      0.96      0.87      4695
#           1       0.38      0.08      0.13      1305
#
# avg / total       0.70      0.77      0.71      6000
#
# #################################
# x_train,y_train score: 0.79525
# x_test,y_test score: 0.761333333333
# f1_score: 0.761333333333
# number of layers: 7
#              precision    recall  f1-score   support
#
#           0       0.78      0.96      0.86      4647
#           1       0.34      0.06      0.11      1353
#
# avg / total       0.68      0.76      0.69      6000
#
# #################################
# x_train,y_train score: 0.792625
# x_test,y_test score: 0.76
# f1_score: 0.76
# number of layers: 8
#              precision    recall  f1-score   support
#
#           0       0.78      0.96      0.86      4654
#           1       0.31      0.06      0.09      1346
#
# avg / total       0.67      0.76      0.69      6000
#
# #################################
# x_train,y_train score: 0.793541666667
# x_test,y_test score: 0.762666666667
# f1_score: 0.762666666667
# number of layers: 9
#              precision    recall  f1-score   support
#
#           0       0.78      0.96      0.86      4648
#           1       0.37      0.07      0.12      1352
#
# avg / total       0.69      0.76      0.70      6000
#
# #################################
# x_train,y_train score: 0.794375
# x_test,y_test score: 0.7585
# f1_score: 0.7585
# number of layers: 10
#              precision    recall  f1-score   support
#
#           0       0.78      0.96      0.86      4661
#           1       0.30      0.06      0.10      1339
#
# avg / total       0.67      0.76      0.69      6000
#
# #################################
# x_train,y_train score: 0.793916666667
# x_test,y_test score: 0.7655
# f1_score: 0.7655
# number of layers: 11
#              precision    recall  f1-score   support
#
#           0       0.78      0.97      0.86      4653
#           1       0.39      0.07      0.13      1347
#
# avg / total       0.69      0.77      0.70      6000
#
# #################################
# x_train,y_train score: 0.792166666667
# x_test,y_test score: 0.775333333333
# f1_score: 0.775333333333
# number of layers: 12
#              precision    recall  f1-score   support
#
#           0       0.79      0.97      0.87      4720
#           1       0.36      0.07      0.12      1280
#
# avg / total       0.70      0.78      0.71      6000
#
# #################################
# x_train,y_train score: 0.794458333333
# x_test,y_test score: 0.7655
# f1_score: 0.7655
# number of layers: 13
#              precision    recall  f1-score   support
#
#           0       0.79      0.96      0.87      4689
#           1       0.32      0.06      0.10      1311
#
# avg / total       0.68      0.77      0.70      6000
#
# #################################
# x_train,y_train score: 0.793458333333
# x_test,y_test score: 0.762833333333
# f1_score: 0.762833333333
# number of layers: 14
#              precision    recall  f1-score   support
#
#           0       0.78      0.96      0.86      4641
#           1       0.38      0.08      0.13      1359
#
# avg / total       0.69      0.76      0.70      6000
#
# #################################
# x_train,y_train score: 0.794041666667
# x_test,y_test score: 0.7675
# f1_score: 0.7675
# number of layers: 15
#              precision    recall  f1-score   support
#
#           0       0.78      0.97      0.87      4653
#           1       0.39      0.06      0.11      1347
#
# avg / total       0.69      0.77      0.70      6000
#
# #################################
# x_train,y_train score: 0.790625
# x_test,y_test score: 0.773666666667
# f1_score: 0.773666666667
# number of layers: 16
#              precision    recall  f1-score   support
#
#           0       0.79      0.96      0.87      4715
#           1       0.37      0.08      0.14      1285
#
# avg / total       0.70      0.77      0.71      6000
#
# #################################
# x_train,y_train score: 0.791291666667
# x_test,y_test score: 0.774
# f1_score: 0.774
# number of layers: 17
#              precision    recall  f1-score   support
#
#           0       0.79      0.96      0.87      4732
#           1       0.32      0.06      0.11      1268
#
# avg / total       0.69      0.77      0.71      6000
#
# #################################
# x_train,y_train score: 0.7955
# x_test,y_test score: 0.764833333333
# f1_score: 0.764833333333
# number of layers: 18
#              precision    recall  f1-score   support
#
#           0       0.78      0.96      0.86      4656
#           1       0.38      0.08      0.13      1344
#
# avg / total       0.69      0.76      0.70      6000
#
# #################################
# x_train,y_train score: 0.794125
# x_test,y_test score: 0.764666666667
# f1_score: 0.764666666667
# number of layers: 19
#              precision    recall  f1-score   support
#
#           0       0.78      0.97      0.86      4662
#           1       0.34      0.06      0.10      1338
#
# avg / total       0.68      0.76      0.69      6000
#
# #################################
# x_train,y_train score: 0.791166666667
# x_test,y_test score: 0.772833333333
# f1_score: 0.772833333333
# number of layers: 20
#              precision    recall  f1-score   support
#
#           0       0.79      0.96      0.87      4719
#           1       0.36      0.09      0.14      1281
#
# avg / total       0.70      0.77      0.71      6000
#
# #################################
# x_train,y_train score: 0.795208333333
# x_test,y_test score: 0.765166666667
# f1_score: 0.765166666667
# number of layers: 21
#              precision    recall  f1-score   support
#
#           0       0.78      0.96      0.86      4654
#           1       0.38      0.08      0.13      1346
#
# avg / total       0.69      0.77      0.70      6000
#
# #################################
# x_train,y_train score: 0.794625
# x_test,y_test score: 0.758333333333
# f1_score: 0.758333333333
# number of layers: 22
#              precision    recall  f1-score   support
#
#           0       0.78      0.96      0.86      4639
#           1       0.35      0.07      0.12      1361
#
# avg / total       0.68      0.76      0.69      6000
#
# #################################
# x_train,y_train score: 0.793375
# x_test,y_test score: 0.761833333333
# f1_score: 0.761833333333
# number of layers: 23
#              precision    recall  f1-score   support
#
#           0       0.78      0.97      0.86      4618
#           1       0.40      0.07      0.12      1382
#
# avg / total       0.69      0.76      0.69      6000
#
# #################################
# x_train,y_train score: 0.793166666667
# x_test,y_test score: 0.766
# f1_score: 0.766
# number of layers: 24
#              precision    recall  f1-score   support
#
#           0       0.79      0.96      0.86      4671
#           1       0.37      0.08      0.13      1329
#
# avg / total       0.69      0.77      0.70      6000
#
# #################################
# x_train,y_train score: 0.791375
# x_test,y_test score: 0.776666666667
# f1_score: 0.776666666667
# number of layers: 25
#              precision    recall  f1-score   support
#
#           0       0.80      0.96      0.87      4743
#           1       0.35      0.08      0.13      1257
#
# avg / total       0.70      0.78      0.72      6000
#
# #################################
# x_train,y_train score: 0.794458333333
# x_test,y_test score: 0.763
# f1_score: 0.763
# number of layers: 26
#              precision    recall  f1-score   support
#
#           0       0.78      0.96      0.86      4670
#           1       0.33      0.07      0.11      1330
#
# avg / total       0.68      0.76      0.70      6000
#
# #################################
# x_train,y_train score: 0.79475
# x_test,y_test score: 0.760666666667
# f1_score: 0.760666666667
# number of layers: 27
#              precision    recall  f1-score   support
#
#           0       0.78      0.97      0.86      4634
#           1       0.36      0.06      0.11      1366
#
# avg / total       0.68      0.76      0.69      6000
#
# #################################
# x_train,y_train score: 0.791666666667
# x_test,y_test score: 0.778833333333
# f1_score: 0.778833333333
# number of layers: 28
#              precision    recall  f1-score   support
#
#           0       0.80      0.97      0.87      4736
#           1       0.37      0.07      0.12      1264
#
# avg / total       0.71      0.78      0.71      6000
#
# #################################
# x_train,y_train score: 0.795541666667
# x_test,y_test score: 0.762
# f1_score: 0.762
# number of layers: 29
#              precision    recall  f1-score   support
#
#           0       0.78      0.97      0.86      4644
#           1       0.35      0.06      0.11      1356
#
# avg / total       0.68      0.76      0.69      6000
#
# #################################
# x_train,y_train score: 0.794375
# x_test,y_test score: 0.765333333333
# f1_score: 0.765333333333
# number of layers: 30
#              precision    recall  f1-score   support
#
#           0       0.78      0.96      0.86      4662
#           1       0.37      0.08      0.13      1338
#
# avg / total       0.69      0.77      0.70      6000
#
# #################################
# x_train,y_train score: 0.794375
# x_test,y_test score: 0.769833333333
# f1_score: 0.769833333333
# number of layers: 31
#              precision    recall  f1-score   support
#
#           0       0.79      0.97      0.87      4681
#           1       0.37      0.07      0.12      1319
#
# avg / total       0.70      0.77      0.70      6000
#
# #################################
# x_train,y_train score: 0.796041666667
# x_test,y_test score: 0.757
# f1_score: 0.757
# number of layers: 32
#              precision    recall  f1-score   support
#
#           0       0.77      0.97      0.86      4613
#           1       0.36      0.06      0.11      1387
#
# avg / total       0.68      0.76      0.69      6000
#
# #################################
# x_train,y_train score: 0.793833333333
# x_test,y_test score: 0.764166666667
# f1_score: 0.764166666667
# number of layers: 33
#              precision    recall  f1-score   support
#
#           0       0.79      0.96      0.86      4669
#           1       0.36      0.08      0.13      1331
#
# avg / total       0.69      0.76      0.70      6000
#
# #################################
# x_train,y_train score: 0.79325
# x_test,y_test score: 0.763833333333
# f1_score: 0.763833333333
# number of layers: 34
#              precision    recall  f1-score   support
#
#           0       0.79      0.96      0.86      4681
#           1       0.34      0.08      0.13      1319
#
# avg / total       0.69      0.76      0.70      6000
#
# #################################
# x_train,y_train score: 0.792958333333
# x_test,y_test score: 0.7615
# f1_score: 0.7615
# number of layers: 35
#              precision    recall  f1-score   support
#
#           0       0.78      0.96      0.86      4650
#           1       0.35      0.07      0.12      1350
#
# avg / total       0.68      0.76      0.69      6000
#
# #################################
# x_train,y_train score: 0.794
# x_test,y_test score: 0.76
# f1_score: 0.76
# number of layers: 36
#              precision    recall  f1-score   support
#
#           0       0.78      0.96      0.86      4651
#           1       0.32      0.06      0.10      1349
#
# avg / total       0.68      0.76      0.69      6000
#
# #################################
# x_train,y_train score: 0.792583333333
# x_test,y_test score: 0.766666666667
# f1_score: 0.766666666667
# number of layers: 37
#              precision    recall  f1-score   support
#
#           0       0.79      0.96      0.87      4687
#           1       0.34      0.07      0.12      1313
#
# avg / total       0.69      0.77      0.70      6000
#
# #################################
# x_train,y_train score: 0.790958333333
# x_test,y_test score: 0.767666666667
# f1_score: 0.767666666667
# number of layers: 38
#              precision    recall  f1-score   support
#
#           0       0.79      0.97      0.87      4679
#           1       0.35      0.07      0.11      1321
#
# avg / total       0.69      0.77      0.70      6000
#
# #################################
# x_train,y_train score: 0.794666666667
# x_test,y_test score: 0.760166666667
# f1_score: 0.760166666667
# number of layers: 39
#              precision    recall  f1-score   support
#
#           0       0.78      0.96      0.86      4627
#           1       0.38      0.08      0.13      1373
#
# avg / total       0.69      0.76      0.69      6000
#
# #################################
# x_train,y_train score: 0.793375
# x_test,y_test score: 0.763
# f1_score: 0.763
# number of layers: 40
#              precision    recall  f1-score   support
#
#           0       0.78      0.96      0.86      4668
#           1       0.34      0.07      0.12      1332
#
# avg / total       0.69      0.76      0.70      6000
#
# #################################
# x_train,y_train score: 0.792
# x_test,y_test score: 0.7775
# f1_score: 0.7775
# number of layers: 41
#              precision    recall  f1-score   support
#
#           0       0.80      0.96      0.87      4739
#           1       0.36      0.08      0.13      1261
#
# avg / total       0.71      0.78      0.72      6000
#
# #################################
# x_train,y_train score: 0.793666666667
# x_test,y_test score: 0.7655
# f1_score: 0.7655
# number of layers: 42
#              precision    recall  f1-score   support
#
#           0       0.78      0.97      0.86      4664
#           1       0.36      0.07      0.11      1336
#
# avg / total       0.69      0.77      0.70      6000
#
# #################################
# x_train,y_train score: 0.793458333333
# x_test,y_test score: 0.767166666667
# f1_score: 0.767166666667
# number of layers: 43
#              precision    recall  f1-score   support
#
#           0       0.78      0.97      0.87      4659
#           1       0.40      0.08      0.13      1341
#
# avg / total       0.70      0.77      0.70      6000
#
# #################################
# x_train,y_train score: 0.79625
# x_test,y_test score: 0.762333333333
# f1_score: 0.762333333333
# number of layers: 44
#              precision    recall  f1-score   support
#
#           0       0.78      0.96      0.86      4647
#           1       0.37      0.08      0.13      1353
#
# avg / total       0.69      0.76      0.70      6000
#
# #################################
# x_train,y_train score: 0.794583333333
# x_test,y_test score: 0.757666666667
# f1_score: 0.757666666667
# number of layers: 45
#              precision    recall  f1-score   support
#
#           0       0.78      0.96      0.86      4618
#           1       0.37      0.08      0.13      1382
#
# avg / total       0.68      0.76      0.69      6000
#
# #################################
# x_train,y_train score: 0.795208333333
# x_test,y_test score: 0.760666666667
# f1_score: 0.760666666667
# number of layers: 46
#              precision    recall  f1-score   support
#
#           0       0.78      0.96      0.86      4664
#           1       0.33      0.07      0.12      1336
#
# avg / total       0.68      0.76      0.70      6000
#
# #################################
# x_train,y_train score: 0.793916666667
# x_test,y_test score: 0.762
# f1_score: 0.762
# number of layers: 47
#              precision    recall  f1-score   support
#
#           0       0.78      0.97      0.86      4605
#           1       0.44      0.08      0.13      1395
#
# avg / total       0.70      0.76      0.69      6000
#
# #################################
# x_train,y_train score: 0.793708333333
# x_test,y_test score: 0.767666666667
# f1_score: 0.767666666667
# number of layers: 48
#              precision    recall  f1-score   support
#
#           0       0.78      0.97      0.87      4652
#           1       0.41      0.07      0.13      1348
#
# avg / total       0.70      0.77      0.70      6000
#
# #################################
# x_train,y_train score: 0.791083333333
# x_test,y_test score: 0.766
# f1_score: 0.766
# number of layers: 49
#              precision    recall  f1-score   support
#
#           0       0.78      0.97      0.87      4665
#           1       0.36      0.07      0.11      1335
#
# avg / total       0.69      0.77      0.70      6000
#
# #################################
# x_train,y_train score: 0.794125
# x_test,y_test score: 0.763333333333
# f1_score: 0.763333333333
# number of layers: 50
#              precision    recall  f1-score   support
#
#           0       0.78      0.96      0.86      4665
#           1       0.34      0.07      0.11      1335
#
# avg / total       0.68      0.76      0.70      6000
#
# #################################
# F1 average: 0.765623333333
